# %%
import somvar as sv

# %%
import os
import pandas as pd

# %%
somatic_test_data_folder = '../../docker/test_conservative_noTGCA/'
vcf_file = '/home/tilman/Apis/somatic/aux_data/BetterB_Batch1_Biallelic_SNP_phased_V2.recode.vcf.gz'

# %%
somvar_dict = sv.base.load_dict(folder=somatic_test_data_folder)

# %%
# have a look at how many variants there are before filtering:
pd.DataFrame([ [key, item.shape[0]] for key,item in somvar_dict.items()], columns=['sample', 'n_variants'])

# %%
#sv_overlap = sv.base.get_sv_overlap(somvar_dict)

# %%
#somvar_dict_filtsv = sv.base.filter_sv(sites=sv_overlap, somvar_dict=somvar_dict,verbose=True)

# %%
# have a look at how many variants there are after filtering:
#pd.DataFrame([ [key, item.shape[0]] for key,item in somvar_dict_filtsv.items()], columns=['sample', 'n_variants'])

# %%
#filtered_germ_sites = sv.germ.filter_germ(somvar_dict=somvar_dict, vcf_file=vcf_file, threads=30)

# %%
#somvar_dict_filtsv_filtgm = sv.base.filter_sv(sites=filtered_germ_sites, somvar_dict=somvar_dict_filtsv,verbose=True)

# %%
# have a look at how many variants there are after filtering:
#pd.DataFrame([ [key, item.shape[0]] for key,item in somvar_dict_filtsv_filtgm.items()], columns=['sample', 'n_variants'])

# %%
discard = sv.discard.load_discard_list(somatic_test_data_folder)
# Out:
# loading data from ../../docker/test_conservative_noTGCA/test_out_0dD3
# done!
# loading data from ../../docker/test_conservative_noTGCA/test_out_0dQ4
# done!
# loading data from ../../docker/test_conservative_noTGCA/test_out_0dW5
# done!
# loading data from ../../docker/test_conservative_noTGCA/test_out_4wD1
# done!
# loading data from ../../docker/test_conservative_noTGCA/test_out_6wW1
# done!
# loading data from ../../docker/test_conservative_noTGCA/test_out_nQ1
# done!
